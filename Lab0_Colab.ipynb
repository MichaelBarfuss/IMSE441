# %% [markdown]
# <a href="https://colab.research.google.com/github/KhmAsif/IMSE441/blob/main/Lab0_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
Data= pd.read_csv('/content/drive/MyDrive/IMSE_441/Dams_2023.csv')
Data
# Out:
#                     Dam_Name  Latitude  Longitude   NID_ID  \
# 0              ELK RIVER DAM   35.2981   -86.0970  TN05101
# 1         TREMAINE RESERVOIR   34.7599  -111.2174  AZ00089
# 2                      BEALE   39.1083  -121.3366  CA10115
# 3                BLACKWELDER   39.1583  -121.3833  CA10116
# 4                     MILLER   39.1699  -121.3966  CA10119
# ...                      ...       ...        ...      ...
# 74091           MEADOW CREEK   39.8066  -107.5472  CO00695
# 74092  HEART LAKE NORTH DIKE   39.7749  -107.3200  CO02889
# 74093   LITTLE HELL'S CANYON   35.0813  -112.4055  AZ00215
# 74094            BEAVER PARK   37.5961  -106.6666  CO00763
# 74095              LYNX LAKE   34.5225  -112.3863  AZ00049
#
#                                   Primary_Purpose State  Year_Completed  \
# 0                                   Flood Control    TN            1952
# 1                                      Irrigation    AZ            1952
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74096 entries, 0 to 74095
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dam_Name           70275 non-null  object
#  1   Latitude           73999 non-null  float64
#  2   Longitude          74001 non-null  float64
#  3   NID_ID             74096 non-null  object
#  4   Primary_Purpose    71375 non-null  object
#  5   State              74096 non-null  object
#  6   Year_Completed     74096 non-null  int64
#  7   Dam_Height         68294 non-null  float64
#  8   Dam_Length         68691 non-null  object
#  9   Drainage_Area      56865 non-null  object
#  10  Max_Discharge      48112 non-null  object
#  11  Max_Storage        72221 non-null  object
#  12  Structural_Height  43770 non-null  float64
#  13  Surface_Area       57129 non-null  object
#  14  Volume             33860 non-null  object
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
Data['Latitude'].describe()
# Out:
# count    73999.000000
# mean        38.535344
# std          4.951658
# min         13.360500
# 25%         34.500000
# 50%         38.986600
# 75%         41.976600
# max         71.266600
# Name: Latitude, dtype: float64
